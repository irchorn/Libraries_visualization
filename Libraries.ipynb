# %%
from matplotlib import pylab

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings 
warnings.filterwarnings("ignore")

# %%
#Import dataset
libraries_file = 'NYPL_Branch_Services_-_Manhattan.csv'
df_libraries = pd.read_csv(libraries_file)
display(df_libraries.head())
# Out:
#   Boro/Central Library                 Network         Branch  ADULT Program  \
# 0            Manhattan  Countee Cullen Network   67th Street           146.0
# 1            Manhattan  Countee Cullen Network    96th Street          154.0
# 2            Manhattan  Countee Cullen Network  115th Street            53.0
# 3            Manhattan  Countee Cullen Network   125th Street          116.0
# 4            Manhattan  Countee Cullen Network        Aguilar           29.0
#
#    ADULT Attendance  YOUNG ADULT Program  YOUNG ADULT Attendance  \
# 0            1298.0                 80.0                   884.0
# 1            2466.0                 90.0                  1710.0
# 2             497.0                 75.0                  1036.0
# 3            1008.0                 46.0                   345.0
# 4             524.0                 28.0                   450.0
#
#    JUVENILE Program  JUVENILE Attendance  OUTREACH SERVICES Program  ...  \
# ...

# %%
df_libraries.shape
# Out:
# (43, 22)

# %%
df_libraries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 22 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Boro/Central Library                 43 non-null     object
#  1   Network                              42 non-null     object
#  2   Branch                               43 non-null     object
#  3   ADULT Program                        42 non-null     float64
#  4   ADULT Attendance                     42 non-null     float64
#  5   YOUNG ADULT Program                  42 non-null     float64
#  6   YOUNG ADULT Attendance               42 non-null     float64
#  7   JUVENILE Program                     42 non-null     float64
#  8   JUVENILE Attendance                  42 non-null     float64
#  9   OUTREACH SERVICES Program            42 non-null     float64
#  10  OUTREACH SERVICES Attendance         42 non-null     float64
# ...

# %%
columns = list(df_libraries.columns)
print(columns)
# Out:
# ['Boro/Central Library', 'Network', 'Branch', 'ADULT Program', 'ADULT Attendance', 'YOUNG ADULT Program', 'YOUNG ADULT Attendance', 'JUVENILE Program', 'JUVENILE Attendance', 'OUTREACH SERVICES Program', 'OUTREACH SERVICES Attendance', ' TOTAL Program', ' TOTAL Attendance', ' REFERENCE TRANSACTIONS Adult', ' REFERENCE TRANSACTIONS Young Adult', ' REFERENCE TRANSACTIONS Juvenile', ' REFERENCE TRANSACTIONS', 'CIRCULATION Adult', 'CIRCULATION Young Adult', 'CIRCULATION Juvenile', 'CIRCULATION', 'Weekly Hours of Public Service']

# %%
#Relationship between ADULT Program and ADULT Attendance

plt.scatter(df_libraries['ADULT Program'], df_libraries['ADULT Attendance'], 
            c = df_libraries['Weekly Hours of Public Service'], cmap = 'winter')

plt.xlabel('ADULT Program')
plt.ylabel('ADULT Attendance')
cbar= plt.colorbar()
cbar.set_label('Weekly Hours')

# %%
#Correlation heatmap
plt.figure(figsize = (10,8))
sns.heatmap(df_libraries.corr(method='spearman'), cmap = 'coolwarm')
plt.show()

# %% [markdown]
# Adult attendance has high correlation with adult program.

# %%
#Sorting library branches by the number of adult programs from high to low
df_top_branches = df_libraries.sort_values('ADULT Program' , ascending=False)

# %%
df_top_branches
# Out:
#    Boro/Central Library                 Network  \
# 42            Manhattan                     NaN
# 39            Manhattan     Seward Park Network
# 19            Manhattan  Countee Cullen Network
# 21            Manhattan     Seward Park Network
# 31            Manhattan     Seward Park Network
# 6             Manhattan  Countee Cullen Network
# 35            Manhattan     Seward Park Network
# 10            Manhattan  Countee Cullen Network
# 1             Manhattan  Countee Cullen Network
# 0             Manhattan  Countee Cullen Network
# 28            Manhattan     Seward Park Network
# 9             Manhattan  Countee Cullen Network
# 29            Manhattan     Seward Park Network
# 15            Manhattan  Countee Cullen Network
# 14            Manhattan  Countee Cullen Network
# 3             Manhattan  Countee Cullen Network
# 5             Manhattan  Countee Cullen Network
# 32            Manhattan     Seward Park Network
# ...

# %%
#Visualizing mean Adult Attendance of Adult Program at top 5 branches
g = sns.catplot(x="ADULT Program", y="ADULT Attendance", col="Branch",
                data=df_top_branches[3:8], kind="bar",
                height=4, aspect=.7);

# %% [markdown]
# 58th Street branch has the highest Adult Attendance.

# %%
#Pie Chart
plt.figure(figsize = (8,6))
slices = [6095, 120, 743]
labels = ['ADULT Attendance', 'JUVENILE Attendance', 'OUTREACH SERVICES Attendance']
explode = [0, 0, 0.1]
plt.pie(slices, labels = labels, explode = explode, autopct = '%1.1f%%', wedgeprops ={'edgecolor':'black'})
plt.title("58th Street Program Attendance")
plt.tight_layout()
plt.show()

# %% [markdown]
# Adult attendance at 58th street branch has the highest percentage.
